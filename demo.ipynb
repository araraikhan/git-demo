# %%
import pandas as pd
import numpy as np

# %%
# Load data
data = pd.read_csv('last_two_years.csv')
data.head()
# Out:
#          Name  Quantity     Price  Year
# 0        АДЬЮ    1225.0   4781.00  2023
# 1        АДЬЮ       0.0      0.00  2024
# 2  АДЬЮ МАКС     2582.0   8066.86  2023
# 3  АДЬЮ МАКС     8617.0  11790.61  2024
# 4  АЗОТ АКТИВ    9990.0   3127.78  2023

# %%
print(data.dtypes)
# Out:
# Name         object
# Quantity    float64
# Price       float64
# Year          int64
# dtype: object

# %%
data['Revenue'] = data['Price'] * data['Quantity']
data.head()
# Out:
#          Name  Quantity     Price  Year       Revenue
# 0        АДЬЮ    1225.0   4781.00  2023  5.856725e+06
# 1        АДЬЮ       0.0      0.00  2024  0.000000e+00
# 2  АДЬЮ МАКС     2582.0   8066.86  2023  2.082863e+07
# 3  АДЬЮ МАКС     8617.0  11790.61  2024  1.015997e+08
# 4  АЗОТ АКТИВ    9990.0   3127.78  2023  3.124652e+07

# %%
data['Revenue'].sum()
# Out:
# 16680408980.865002

# %%
# !pip install plotnine
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.9/89.9 kB 667.3 kB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 3.0 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 kB 7.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.6/12.6 MB 5.9 MB/s eta 0:00:0000:0100:01
# ...
#   Attempting uninstall: pandas
#     Found existing installation: pandas 2.1.4
#     Uninstalling pandas-2.1.4:
#       Successfully uninstalled pandas-2.1.4
# ...

# %%
from plotnine.data import economics
from plotnine import ggplot, aes, geom_line

# %%
# !pip install ggplot
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 2.9 MB/s eta 0:00:0000:0100:010m
# ...

# %%
from ggplot import *
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[63], line 1
# ----> 1 from ggplot import *
#
# File /opt/anaconda3/lib/python3.11/site-packages/ggplot/__init__.py:19
#      14         mpl.use(env_backend)
#      16 _set_mpl_backend()
# ---> 19 from .geoms import geom_area, geom_blank, geom_boxplot, geom_line, geom_point, geom_jitter, geom_histogram, geom_density, geom_hline, geom_vline, geom_bar, geom_abline, geom_tile, geom_rect, geom_bin2d, geom_step, geom_text, geom_path, geom_ribbon, geom_now_its_art, geom_violin, geom_errorbar, geom_polygon
#      20 from .stats import stat_smooth, stat_density
#      22 from .facets import facet_wrap, facet_grid, Facet
#
# File /opt/anaconda3/lib/python3.11/site-packages/ggplot/geoms/__init__.py:1
# ----> 1 from .geom_abline import geom_abline
#       2 from .geom_area import geom_area
#       3 from .geom_bar import geom_bar
#
# ...

# %%
# !pip -u pandas
# Out:
# Usage:
#   pip <command> [options]
#
# no such option: -u

# %%
for i in range(data.shape[0]//2):
    ggplot(aes(x="Year", weight="Quantity"), data[i:i+1]) + geom_bar()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[60], line 2
#       1 for i in range(data.shape[0]//2):
# ----> 2     ggplot(aes(x="Year", weight="Quantity"), data[i:i+1]) + ggplot.geom_bar()
#
# AttributeError: type object 'ggplot' has no attribute 'geom_bar'

# %%
(
    ggplot(data[2:4])  # What data to use
    + aes(x="Price", y="")  # What variable to use
    + geom_line()  # Geometric object to use for drawing
)

# %%
# distribution plot of price by product: two by two grid
(  ggplot(data, aes(x='Price', fill='Name')) +
    #geom_density(alpha=0.6) +
    #facet_wrap('~Name', ncol=2) +
    #theme_minimal() +
    theme(figure_size=(10, 5)) +  # Adjust the width and height here
    labs(title='Price Distribution by Product', x='Price', y='Density', fill='Product'))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[34], line 6
#       1 # distribution plot of price by product: two by two grid
#       2 (  ggplot(data, aes(x='Price', fill='Name')) +
#       3     #geom_density(alpha=0.6) +
#       4     #facet_wrap('~Name', ncol=2) +
#       5     #theme_minimal() +
# ----> 6     theme(figure_size=(10, 5)) +  # Adjust the width and height here
#       7     labs(title='Price Distribution by Product', x='Price', y='Density', fill='Product'))
#
# NameError: name 'theme' is not defined
